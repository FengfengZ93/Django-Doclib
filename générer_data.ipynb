# %%
import random
import pandas as pd

# %%
poids = [random.randint(80, 82) for i in range(20)]
taille = [random.randint(180, 180) for i in range(20)]

# %%
taille

# %%
patients = [("P"+str(i), "P"+str(i)+"MDP") for i in range(10000, 10030)]
medecins = [("M"+str(i), "M"+str(i)+"MDP") for i in range(10000, 10030)]

# %%
patients
# Out:
# [('P10000', 'P10000MDP'),
#  ('P10001', 'P10001MDP'),
#  ('P10002', 'P10002MDP'),
#  ('P10003', 'P10003MDP'),
#  ('P10004', 'P10004MDP'),
#  ('P10005', 'P10005MDP'),
#  ('P10006', 'P10006MDP'),
#  ('P10007', 'P10007MDP'),
#  ('P10008', 'P10008MDP'),
#  ('P10009', 'P10009MDP'),
#  ('P10010', 'P10010MDP'),
#  ('P10011', 'P10011MDP'),
#  ('P10012', 'P10012MDP'),
#  ('P10013', 'P10013MDP'),
#  ('P10014', 'P10014MDP'),
#  ('P10015', 'P10015MDP'),
#  ('P10016', 'P10016MDP'),
#  ('P10017', 'P10017MDP'),
#  ('P10018', 'P10018MDP'),
#  ('P10019', 'P10019MDP'),
#  ('P10020', 'P10020MDP'),
#  ('P10021', 'P10021MDP'),
#  ('P10022', 'P10022MDP'),
#  ('P10023', 'P10023MDP'),
#  ('P10024', 'P10024MDP'),
#  ('P10025', 'P10025MDP'),
#  ('P10026', 'P10026MDP'),
#  ('P10027', 'P10027MDP'),
#  ('P10028', 'P10028MDP'),
#  ('P10029', 'P10029MDP')]

# %%
dfPatients = pd.DataFrame(patients, columns=["username", "motDePasse"])
dfPatients
# Out:
#    username motDePasse
# 0    P10000  P10000MDP
# 1    P10001  P10001MDP
# 2    P10002  P10002MDP
# 3    P10003  P10003MDP
# 4    P10004  P10004MDP
# 5    P10005  P10005MDP
# 6    P10006  P10006MDP
# 7    P10007  P10007MDP
# 8    P10008  P10008MDP
# 9    P10009  P10009MDP
# 10   P10010  P10010MDP
# 11   P10011  P10011MDP
# 12   P10012  P10012MDP
# 13   P10013  P10013MDP
# 14   P10014  P10014MDP
# 15   P10015  P10015MDP
# 16   P10016  P10016MDP
# 17   P10017  P10017MDP
# 18   P10018  P10018MDP
# 19   P10019  P10019MDP
# 20   P10020  P10020MDP
# 21   P10021  P10021MDP
# 22   P10022  P10022MDP
# 23   P10023  P10023MDP
# 24   P10024  P10024MDP
# 25   P10025  P10025MDP
# 26   P10026  P10026MDP
# 27   P10027  P10027MDP
# 28   P10028  P10028MDP
# 29   P10029  P10029MDP

# %%
for a, b in dfPatients.iterrows():
  print(b.username)
# Out:
# P10000
# P10001
# P10002
# P10003
# P10004
# P10005
# P10006
# P10007
# P10008
# P10009
# P10010
# P10011
# P10012
# P10013
# P10014
# P10015
# P10016
# P10017
# P10018
# P10019
# P10020
# P10021
# P10022
# P10023
# P10024
# P10025
# P10026
# P10027
# P10028
# P10029

# %%
pd.DataFrame(patients, columns=["username", "motDePasse"]).to_csv("listePatients.csv", index=False)

# %%
pd.DataFrame(medecins, columns=["username", "motDePasse"]).to_csv("listeMedecins.csv", index=False)

# %%
pd.read_csv("/content/listePatients.csv")
# Out:
#    username motDePasse
# 0    P10000  P10000MDP
# 1    P10001  P10001MDP
# 2    P10002  P10002MDP
# 3    P10003  P10003MDP
# 4    P10004  P10004MDP
# 5    P10005  P10005MDP
# 6    P10006  P10006MDP
# 7    P10007  P10007MDP
# 8    P10008  P10008MDP
# 9    P10009  P10009MDP
# 10   P10010  P10010MDP
# 11   P10011  P10011MDP
# 12   P10012  P10012MDP
# 13   P10013  P10013MDP
# 14   P10014  P10014MDP
# 15   P10015  P10015MDP
# 16   P10016  P10016MDP
# 17   P10017  P10017MDP
# 18   P10018  P10018MDP
# 19   P10019  P10019MDP
# 20   P10020  P10020MDP
# 21   P10021  P10021MDP
# 22   P10022  P10022MDP
# 23   P10023  P10023MDP
# 24   P10024  P10024MDP
# 25   P10025  P10025MDP
# 26   P10026  P10026MDP
# 27   P10027  P10027MDP
# 28   P10028  P10028MDP
# 29   P10029  P10029MDP
